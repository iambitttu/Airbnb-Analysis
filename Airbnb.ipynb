# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\bittu\anaconda3\lib\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\bittu\anaconda3\lib\site-packages (from pymongo) (2.3.0)

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://bittukrsingh17:eOPgC1Rv3k31Q79a@cluster0.14au0ex.mongodb.net/?retryWrites=true&w=majority")
db = client.test
db
# Out:
# Database(MongoClient(host=['ac-3du7cdp-shard-00-01.14au0ex.mongodb.net:27017', 'ac-3du7cdp-shard-00-02.14au0ex.mongodb.net:27017', 'ac-3du7cdp-shard-00-00.14au0ex.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-33jmak-shard-0', tls=True), 'test')

# %%
db = client['sample_airbnb']
col = db['listingsAndReviews']

# %%
col
# Out:
# Collection(Database(MongoClient(host=['ac-3du7cdp-shard-00-01.14au0ex.mongodb.net:27017', 'ac-3du7cdp-shard-00-02.14au0ex.mongodb.net:27017', 'ac-3du7cdp-shard-00-00.14au0ex.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-33jmak-shard-0', tls=True), 'sample_airbnb'), 'listingsAndReviews')

# %%
for i in col.find():
    print(i)
    break
# Out:
# {'_id': '10038496', 'listing_url': 'https://www.airbnb.com/rooms/10038496', 'name': 'Copacabana Apartment Posto 6', 'summary': 'The Apartment has a living room, toilet, bedroom (suite) and American kitchen. Well located, on the Copacabana beach block a 05 Min. walk from Ipanema beach (Arpoador). Internet wifi, cable tv, air conditioning in the bedroom, ceiling fans in the bedroom and living room, kitchen with microwave, cooker, Blender, dishes, cutlery and service area with fridge, washing machine, clothesline for drying clothes and closet with several utensils for use.  The property boasts 45 m2.', 'space': "The apartment has a living room, wash room, suite and an American kitchen. The bedroom has a double bed and there's a bunk bed in the living room. It is very well located, in the Copacabana beach block and just a few blocks from Arpoador and Ipanema. You can walk to any of those beaches. It has internet wifi, tv, air conditioning in the bedroom, ceiling fans in the living room and the bedroom and an equipped kitchen with cooker, fridge, washing machine, microwave and utensils. Ease of public transportation, banks, markets and restaurants.", 'description': "The Apartment has a living room, toilet, bedroom (suite) and American kitchen. Well located, on the Copacabana beach block a 05 Min. walk from Ipanema beach (Arpoador). Internet wifi, cable tv, air conditioning in the bedroom, ceiling fans in the bedroom and living room, kitchen with microwave, cooker, Blender, dishes, cutlery and service area with fridge, washing machine, clothesline for drying clothes and closet with several utensils for use.  The property boasts 45 m2. The apartment has a living room, wash room, suite and an American kitchen. The bedroom has a double bed and there's a bunk bed in the living room. It is very well located, in the Copacabana beach block and just a few blocks from Arpoador and Ipanema. You can walk to any of those beaches. It has internet wifi, tv, air conditioning in the bedroom, ceiling fans in the living room and the bedroom and an equipped kitchen with cooker, fridge, washing machine, microwave and utensils. Ease of public transportation, banks, mar", 'neighborhood_overview': 'Copacabana in the South zone is the district that offers the greatest number of options for tourists, transport, restaurants, banks, pharmacies and commerce in general are in abundance in all the blocks of the neighborhood.', 'notes': '', 'transit': 'On the street there is plenty of transport and the subway station is nearby (06 blocks). To get to the Christ the Redeemer Statue there are the options of Metro, bus (at the door) or taxi and the Sugar Loaf (pão de açúcar), bus (at the door), cab, all very close.', 'access': 'todo o espaço.', 'interaction': 'Contact telephone numbers if needed: Valeria ((PHONE NUMBER HIDDEN) (URL HIDDEN) ((PHONE NUMBER HIDDEN) cell phone (URL HIDDEN) (021) mobile/(PHONE NUMBER HIDDEN) José (URL HIDDEN)Concierge support; Fernando (caretaker boss) business hours.', 'house_rules': 'Entreguem o imóvel conforme receberam e respeitem as regras do condomínio para não serem incomodados.  Não danificar os utensílios e tudo que se refere as boas condições referentes ao mesmo . Não fazer barulho após às 22:00  até às 8:00. Usar entrada de serviço se estiver molhado voltando da praia.', 'property_type': 'Apartment', 'room_type': 'Entire home/apt', 'bed_type': 'Real Bed', 'minimum_nights': '3', 'maximum_nights': '75', 'cancellation_policy': 'strict_14_with_grace_period', 'last_scraped': datetime.datetime(2019, 2, 11, 5, 0), 'calendar_last_scraped': datetime.datetime(2019, 2, 11, 5, 0), 'first_review': datetime.datetime(2016, 1, 18, 5, 0), 'last_review': datetime.datetime(2019, 1, 28, 5, 0), 'accommodates': 4, 'bedrooms': 1, 'beds': 3, 'number_of_reviews': 70, 'bathrooms': Decimal128('2.0'), 'amenities': ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air conditioning', 'Kitchen', 'Paid parking off premises', 'Smoking allowed', 'Doorman', 'Elevator', 'B ...

# %%
data=[]
for i in col.find():
    data.append(i)
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data[5554]
# Out:
# {'_id': '9993190',
#  'listing_url': 'https://www.airbnb.com/rooms/9993190',
#  'name': 'Just Steps from the Ocean at Premier Platinum Townhouse Puamana 64-1',
#  'summary': 'Relax Hawaiian Style in Gated Community on Oceanfront Property. Call us NOW for Special March Rates!',
#  'space': '***NOTE: THE OCEAN INFINITY POOL ("POOL 1"0 WILL BE CLOSED FOR REPAIRS 4/9-4/15/19. ALTERNATE POOLS ("POOL 2" AND "POOL 3") WILL REMAIN OPEN. Come stay with us and enjoy island living Puamana-style! Swim and surf at the beach, soak up the sun and cool off in the oceanfront pool, play tennis, or relax under the coconut trees and enjoy stunning sunset views of Lanai’i, Kahoolawe, and Molokai.   Relax and enjoy Coconut Condos Premier Platinum 2bd/2ba Puamana townhouse in Lahaina, Maui.  1,150 sq. ft. townhouse includes a king bed in the master bedroom, a queen sofa sleeper in the family room and two twin beds in the upstairs loft to accommodate up to 6 guests. Private lanai with BBQ grill and table.  Designer furniture upgrades throughout the townhouse Custom bedding by Maka Sea, designed in Hawaii and made in Bali Cold Towel Amenity upon arrival in the townhouse Luxury spa products from Malie Organics, made in Hawaii 40”-55” Smart, flat screen TV in the living room and bedroom Calphalon ',
#  'description': 'Relax Hawaiian Style in Gated Community on Oceanfront Property. Call us NOW for Special March Rates! ***NOTE: THE OCEAN INFINITY POOL ("POOL 1"0 WILL BE CLOSED FOR REPAIRS 4/9-4/15/19. ALTERNATE POOLS ("POOL 2" AND "POOL 3") WILL REMAIN OPEN. Come stay with us and enjoy island living Puamana-style! Swim and surf at the beach, soak up the sun and cool off in the oceanfront pool, play tennis, or relax under the coconut trees and enjoy stunning sunset views of Lanai’i, Kahoolawe, and Molokai.   Relax and enjoy Coconut Condos Premier Platinum 2bd/2ba Puamana townhouse in Lahaina, Maui.  1,150 sq. ft. townhouse includes a king bed in the master bedroom, a queen sofa sleeper in the family room and two twin beds in the upstairs loft to accommodate up to 6 guests. Private lanai with BBQ grill and table.  Designer furniture upgrades throughout the townhouse Custom bedding by Maka Sea, designed in Hawaii and made in Bali Cold Towel Amenity upon arrival in the townhouse Luxury spa products from M',
#  'neighborhood_overview': 'Location: Located at the south end of Lahaina town and short bike ride to Lahaina`s famous Front Street that includes the harbor, shopping, art galleries and restaurants and Banyan tree square. Located a short walking distance to the charming 505 Front Street shopping center that has unique shops, award winning restaurants, convenience store, and the Polynesian Luau `The Feast at Lele`. ½ mile stretch of beach is right in front of the property! (Please note that Puamana`s sandy beach is seasonal.) You can surf right out front of Puamana, or head down the road to 505 Beach and surf Breakwall and Harbors surf breaks. Puamana Beach park is right next door and Launiupoko beach park is within 2-5 minutes drive—both offer beginner to intermediate surf breaks. Just minutes from Ka`anapali beach resort area, world-class golf courses and the renowned Kapalua resort (can take the $2 Maui Bus). 20 minutes from Kapalua Airport & 45 minutes from Kahului airport.',
#  'notes': 'Puamana Resort requires a $10/day resort fee which includes daily parking for one vehicle and use of the resort facilities (tennis courts, swimming pools, and clubhouse).  This fee is included in your nightly rate.  You will need to register you car at the Office in the Clubhouse.',
#  'transit': 'You can walk to most attractions within Lahaina and on Front Street! If you do want to travel around the island, the nearest Maui bus stop is at the Wharf Center or you can easily work with a local taxi or car rental company for transportation needs.',
#  'access': 'Guests will have access to the 3 pools in the community with gate access codes.  Tennis courts are available for use with sign-up sheets in the Clubhouse *rules apply.  The Clubhouse gym is available $10/day+tax or $25/week+tax; a $20 cash deposit for the key is collected at the Clubhouse office.',
#  'interaction': 'We do most of our interaction through emails and phone calls but we are also on property every day. We also provide different ways to contact us, as we want to be accessible if you have any questions before or during your stay! We try to make checking in and out as easy as possible. When you make a reservation with us, we will send you a door code specific for your reservation and condo unit two weeks prior to your stay. You do not have to worry about losing a key or having to check in at a front desk!',
#  'house_rules': 'As a guest of Coconut Condos, I agree to the following terms and conditions: TERMS AND CONDITIONS 1. Agreement:  The Owners and Guests agree as follows: Guest is over the age of 21 and will be an occupant of the unit during the entire reserved period. Other occupants will be family members, friends, or responsible children. No door key codes or key will be issued to anyone other than the tenant listed on rental agreement. The maximum number of guests per 2bd/2ba condominium is limited to six (6) persons. The maximum number of guests per 1bd/1ba condominium is limited to four (4) persons. This property requires a (3) night minimum stay and longer stays may be required during holiday periods. Rates are subject to change without notice. 2. Pets:  In the event that your animal is a service animal, please send official documents to our office as soon as possible and we can register the paperwork. It is Coconut Condos policy that all Service animals are registered. It is Coconut Condos polic',
#  'property_type': 'Townhouse',
#  'room_type': 'Entire home/apt',
#  'bed_type': 'Real Bed',
#  'minimum_nights': '3',
#  'maximum_nights': '365',
#  'cancellation_policy': 'strict_14_with_grace_period',
#  'last_scraped': datetime.datetime(2019, 3, 6, 5, 0),
#  'calendar_last_scraped': datetime.datetime(2019, 3, 6, 5, 0),
#  'first_review': datetime.datetime(2016, 4, 6, 4, 0),
#  'last_review': datetime.datetime(2018, 8, 20, 4, 0),
#  'accommodates': 6,
#  'bedrooms': 2,
#  'beds': 4,
#  'number_of_reviews': 15,
#  'bathrooms': Decimal128('2.0'),
#  'amenities': ['TV',
#   'Wifi',
#   'Air conditioning',
#   'Pool',
#   'Kitchen',
#   'Free parking on premises',
#   'Gym',
#   'Family/kid friendly',
#   'Washer',
#   'Dryer',
#   'Smoke detector',
#   'First aid kit',
#   'Fire extinguisher',
#   'Essentials',
#   'Shampoo'],
#  'price': Decimal128('220.00'),
#  'security_deposit': Decimal128('200.00'),
#  'cleaning_fee': Decimal128('315.00'),
#  'extra_people': Decimal128('0.00'),
#  'guests_included': Decimal128('1'),
#  'images': {'thumbnail_url': '',
#   'medium_url': '',
#   'picture_url': 'https://a0.muscache.com/im/pictures/be1978c5-69cc-4100-99bc-2e84c1d65644.jpg?aki_policy=large',
#   'xl_picture_url': ''},
#  'host': {'host_id': '51013381',
#   'host_url': 'https://www.airbnb.com/users/show/51013381',
#   'host_name': 'Coconut Condos',
#   'host_location': 'Lahaina, Hawaii, United States',
#   'host_about': '',
#   'host_response_time': 'within an hour',
#   'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/fa071e13-8082-4c82-9731-5abb5b23e027.jpg?aki_policy=profile_small',
#   'host_picture_url': 'https://a0.muscache.com/im/pictures/fa071e13-8082-4c82-9731-5abb5b23e027.jpg?aki_policy=profile_x_medium',
#   'host_neighbourhood': '',
#   'host_response_rate': 99,
#   'host_is_superhost': False,
#   'host_has_profile_pic': True,
#   'host_identity_verified': True,
#   'host_listings_count': 58,
#   'host_total_listings_count': 58,
#   'host_verifications': ['email', 'phone', 'reviews', 'kba', 'work_email']},
#  'address': {'street': 'Lahaina, HI, United States',
#   'suburb': 'Lahaina',
#   'government_area': 'Lahaina',
#   'market': 'Maui',
#   'country': 'United States',
#   'country_code': 'US',
#   'location': {'type': 'Point',
#    'coordinates': [-156.66752, 20.85894],
#    'is_location_exact': False}},
#  'availability': {'availability_30': 0,
#   'availability_60': 8,
#   'availability_90': 31,
#   'availability_365': 258},
#  'review_scores': {'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9,
#   'review_scores_rating': 92},
#  'reviews': [{'_id': '68762225',
#    'date': datetime.datetime(2016, 4, 6, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '36755630',
#    'reviewer_name': 'Grace',
#    'comments': "Pro:\r\n  1. Frindly and great communications before arrival and during our stay.\r\n   2. Cozy unit in convenient location\r\n    3. Comfortable mattress for all three beds (unlike some vacation rentals, super soft mattress, hard to fall in sleep with)\r\n    4. A/C in both bedrooms were cold enough during our stay.\r\n\r\nCon:\r\n  1. Ghost ants on kitchen countertop and master bathroom sinktop.\r\n  2. Some badly scratched pots\r\n  3.  Refrigerator water filter need to be replaced.\r\n  4. 1st bathroom toilet was not sturdy\r\n   5. 1st bathroom bath tub water faucet was reversed (turn left was cold and right was hot) \r\n   6. Living Room A/C was not cold at all during our stay.\r\n   7. Master bath room sink water smell very bad, have some oder...need to check the water pipe \r\n   8. We didn't receive the update front gate code during weekend. No one to ask during weekend. \r\n  9. Couldn't reach the host or the management during weekend.\r\n\r\n\r\n"},
#   {'_id': '87981416',
#    'date': datetime.datetime(2016, 7, 22, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '13166419',
#    'reviewer_name': 'Gemma',
#    'comments': 'The apartment was perfect, great location in front of a surf beach and a 15 minute walk into Lahaina town. The apartment catered for our every need, even a first aid kit for any cuts for beginner surfers! A highlight is the Oceanside pool. Thanks for a very special stay. : ) '},
#   {'_id': '93184184',
#    'date': datetime.datetime(2016, 8, 11, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '44822342',
#    'reviewer_name': 'Cristiana',
#    'comments': "This property was wonderful and perfect! In fact it has been one of the best we have stayed at with Airbnb and we almost always stay with Airbnb all over the world! Everything was as advertised and better. Everything worked, it was comfortable, it was light and spacious and you could see that little extra effort put into the furnishings and the amenities and it was appreciated. The kitchen was totally stocked with everything you could need to prepare your own meals. I can't believe it even had a rice cooker!? This property made our vacation easy, relaxing and memorable. We would highly recommend this property and will definitely stay here again if we come back to Maui. Thank you Coconut Condos and Puamana 64-1!!"},
#   {'_id': '105726524',
#    'date': datetime.datetime(2016, 10, 2, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '23090656',
#    'reviewer_name': 'Chris',
#    'comments': "Cozy, clean, and tastefully designed condo unit in south Lahaina. It's secure and quiet with nice little perks like an oceanside pool , backyard surf breaks and not to mention only about a 10 - 15 min stroll from downtown Lahaina ! Hard to beat this spot !"},
#   {'_id': '124083212',
#    'date': datetime.datetime(2017, 1, 1, 5, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '12861138',
#    'reviewer_name': 'Katharina',
#    'comments': 'We stayed in Puamana for one week with four people. The accommodation was great - it looked the same like on the photos. Everything was available. \nWithin Puamana it was quite and all people were really friendly. The access to the pool at the ocean was 30 seconds away - not too overcrowded but a perfect and quite area to relax. \nThe Check-In and Check-Out was easy. \nWe loved our stay. '},
#   {'_id': '129582461',
#    'date': datetime.datetime(2017, 1, 31, 5, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '4706145',
#    'reviewer_name': 'Elizabeth',
#    'comments': 'Safe walk into Lahaina town.  Quiet property with well-equipped kitchen.  Comfortable stay!'},
#   {'_id': '140267213',
#    'date': datetime.datetime(2017, 3, 28, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '39352896',
#    'reviewer_name': 'Debbie',
#    'comments': 'Had a good time'},
#   {'_id': '141778556',
#    'date': datetime.datetime(2017, 4, 4, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '61850104',
#    'reviewer_name': 'Carolyn',
#    'comments': 'We loved Puamana! I highly recommend staying here. The grounds are gorgeous and there is an incredible ocean pool to swim in. You are close to Lahaina and all of the surfing action (for beginners) and great restaurants. Puamana is so low-key and quiet, we loved it. Our condo was not on the water but a short walking distance to the main clubhouse and sitting areas. '},
#   {'_id': '162420460',
#    'date': datetime.datetime(2017, 6, 20, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '116039989',
#    'reviewer_name': 'Martin',
#    'comments': 'Tolle Unterkunft in einer wunderschönen Anlage. Der Pool direkt am Meer ist schlichtweg sensationell. Das Apartment ist gut ausgestattet und bietet alles, was man für einen wunderschönen Urlaub braucht.'},
#   {'_id': '191021698',
#    'date': datetime.datetime(2017, 9, 5, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '51418988',
#    'reviewer_name': 'Jaime',
#    'comments': 'They were really accommodating to ensure we could get in in time for my 1 year old to take her nap.  Loved thecondo and location. Highly recommend!'},
#   {'_id': '215802077',
#    'date': datetime.datetime(2017, 12, 1, 5, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '6298983',
#    'reviewer_name': 'Cortney',
#    'comments': 'The Condo\nThe condo was a great space, plenty of room for our family of 4, and well equipped. Modern chic furnishings, the bathrooms and kitchen are outdated, but this didn\'t bother me. The upstairs kids area was awesome. Loved the games, kids books, and toys, and the kids loved having their own space to hang out. Comfortable bed, and great dining area. There was a closet with outdoor things: chairs, boogie boards, sand toys. I had a question and the Coconut Condos team was great at getting back to me ASAP and taking care of it. My only complaint is that the condo could have been cleaner, the floors left our socks dirty, and there were dirty plates in the cupboards.\n\nThe Resort\nPuamana is a beautifully maintained place, with amazing plantings and foliage everywhere, it feels very lush. We were there with 2 young children and I did feel a retirement community vibe. It is not all short term rentals, some people live there more permanently. There are a lot of rules for the resort and a lot about keeping "quiet enjoyment" and the best pool, the oceanfront pool, is reserved for "quiet enjoyment" and though it doesn\'t specifically say "no kids" we were given the stink eye by all the adults sunbathing when we tried to take our kids there. The other two pools, designated as the kids pools, are just basic and not oceanfront. There are ocean views from everywhere but the actual beach is rocky/sandy and narrow and didn\'t look good for swimming or sunbathing. I would highly recommend this place to couples traveling without kids.'},
#   {'_id': '230037614',
#    'date': datetime.datetime(2018, 1, 26, 5, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '5985353',
#    'reviewer_name': 'Andrew',
#    'comments': 'We had a great stay. They make it very easy for families: the beach kit has everything you could ask for and more (chairs, umbrellas, boogie boards, beach toys, even a wagon), the kids play area has books and puzzles, they provide a pack n’ play with a fresh crib sheet, and there’s a washer and dryer. There were also many families at the resort during our stay. There’s a small park with a climber, and 3 pools, though no real shallow area for small kids which limited swimming at the resort. \n\nSome spaces in the condo are a little dated but we had no complaints. You don’t have an ocean view from the condo but you’re very close to the ocean. The beach in front of the resort was washed out at this time of year, but baby beach is just a 10 minute drive away and Puamana beach is walkable from the condo. \n\nThe condo is a short drive to downtown Lahaina, which is a wonderful town with great restaurants and a harbor from which many tours and activities depart. The location is central and very convenient to other parts of the island. We had a wonderful vacation and would stay here again.'},
#   {'_id': '267808615',
#    'date': datetime.datetime(2018, 5, 22, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '265335',
#    'reviewer_name': 'Roberta',
#    'comments': 'Puamana is a fantastic location, close to town of Lahaina yet very private and quiet.  Loved the pool!'},
#   {'_id': '279841845',
#    'date': datetime.datetime(2018, 6, 21, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '74697307',
#    'reviewer_name': 'Amanda',
#    'comments': 'We loved our stay here. It’s close to the action of Lahania, but far enough away from the hustle and bustle to be relaxing. Our host was very responsive to all our questions, and the unit was perfect for our needs. The grounds were lovely and the views from the pool area were incredible. I would stay here again if I was coming to Lahania.'},
#   {'_id': '311261442',
#    'date': datetime.datetime(2018, 8, 20, 4, 0),
#    'listing_id': '9993190',
#    'reviewer_id': '3140787',
#    'reviewer_name': 'Harold',
#    'comments': 'Condo is located in gated community with 3 pools, one of which has a beautiful view overlooking the ocean. AC is effective at keeping you cool. Host is very professional and communicates well. Late checkout was a very valuable option and helped greatly.'}]}

# %%
import pandas as pd

# Convert MongoDB cursor to DataFrame
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (5555, 42)

# %%
df.head(3)
# Out:
#         _id                            listing_url  \
# 0  10038496  https://www.airbnb.com/rooms/10038496
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2  10006546  https://www.airbnb.com/rooms/10006546
#
#                            name  \
# 0  Copacabana Apartment Posto 6
# 1  Horto flat with small garden
# 2       Ribeira Charming Duplex
#
#                                              summary  \
# 0  The Apartment has a living room, toilet, bedro...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
# 2  Fantastic duplex apartment with three bedrooms...
#
#                                                space  \
# 0  The apartment has a living room, wash room, su...
# 1  Lovely one bedroom + sofa-bed in the living ro...
# 2  Privileged views of the Douro River and Ribeir...
#
#                                          description  \
# 0  The Apartment has a living room, toilet, bedro...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
# 2  Fantastic duplex apartment with three bedrooms...
#
#                                neighborhood_overview  \
# 0  Copacabana in the South zone is the district t...
# 1  This charming ground floor flat is located in ...
# 2  In the neighborhood of the river, you can find...
#
#                                                notes  \
# 0
# 1  There´s a table in the living room now, that d...
# 2  Lose yourself in the narrow streets and stairc...
#
#                                              transit  \
# 0  On the street there is plenty of transport and...
# 1  Easy access to transport (bus, taxi, car) and ...
# 2  Transport: • Metro station and S. Bento railwa...
#
#                                               access  ... guests_included  \
# 0                                     todo o espaço.  ...               3
# 1                                                     ...               1
# 2  We are always available to help guests. The ho...  ...               6
#
#                                               images  \
# 0  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                 host  \
# 0  {'host_id': '51530266', 'host_url': 'https://w...
# 1  {'host_id': '1282196', 'host_url': 'https://ww...
# 2  {'host_id': '51399391', 'host_url': 'https://w...
#
#                                              address  \
# 0  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 1  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 2  {'street': 'Porto, Porto, Portugal', 'suburb':...
#
#                                         availability  \
# 0  {'availability_30': 7, 'availability_60': 19, ...
# 1  {'availability_30': 0, 'availability_60': 0, '...
# 2  {'availability_30': 28, 'availability_60': 47,...
#
#                                        review_scores  \
# 0  {'review_scores_accuracy': 10, 'review_scores_...
# 1                                                 {}
# 2  {'review_scores_accuracy': 9, 'review_scores_c...
#
#                                              reviews weekly_price  \
# 0  [{'_id': '60037020', 'date': 2016-01-18 05:00:...          NaN
# 1                                                 []      1492.00
# 2  [{'_id': '58663741', 'date': 2016-01-03 05:00:...          NaN
#
#   monthly_price reviews_per_month
# 0           NaN               NaN
# 1       4849.00               NaN
# 2           NaN               NaN
#
# [3 rows x 42 columns]

# %%
df.describe()
# Out:
#        accommodates     bedrooms         beds  number_of_reviews  \
# count   5555.000000  5550.000000  5542.000000        5555.000000
# mean       3.505851     1.411712     2.071454          27.606481
# std        2.297019     1.041942     1.619660          49.798376
# min        1.000000     0.000000     0.000000           0.000000
# 25%        2.000000     1.000000     1.000000           1.000000
# 50%        3.000000     1.000000     2.000000           5.000000
# 75%        4.000000     2.000000     3.000000          32.000000
# max       16.000000    20.000000    25.000000         533.000000
#
#        reviews_per_month
# count          94.000000
# mean            1.712766
# std             1.492795
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             2.000000
# max            10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _id                    5555 non-null   object
#  1   listing_url            5555 non-null   object
#  2   name                   5555 non-null   object
#  3   summary                5555 non-null   object
#  4   space                  5555 non-null   object
#  5   description            5555 non-null   object
#  6   neighborhood_overview  5555 non-null   object
#  7   notes                  5555 non-null   object
#  8   transit                5555 non-null   object
#  9   access                 5555 non-null   object
#  10  interaction            5555 non-null   object
#  11  house_rules            5555 non-null   object
#  12  property_type          5555 non-null   object
#  13  room_type              5555 non-null   object
#  14  bed_type               5555 non-null   object
#  15  minimum_nights         5555 non-null   object
#  16  maximum_nights         5555 non-null   object
#  17  cancellation_policy    5555 non-null   object
#  18  last_scraped           5555 non-null   datetime64[ns]
#  19  calendar_last_scraped  5555 non-null   datetime64[ns]
#  20  first_review           4167 non-null   datetime64[ns]
#  21  last_review            4167 non-null   datetime64[ns]
#  22  accommodates           5555 non-null   int64
#  23  bedrooms               5550 non-null   float64
#  24  beds                   5542 non-null   float64
#  25  number_of_reviews      5555 non-null   int64
#  26  bathrooms              5545 non-null   object
#  27  amenities              5555 non-null   object
#  28  price                  5555 non-null   object
#  29  security_deposit       3471 non-null   object
#  30  cleaning_fee           4024 non-null   object
#  31  extra_people           5555 non-null   object
#  32  guests_included        5555 non-null   object
#  33  images                 5555 non-null   object
#  34  host                   5555 non-null   object
#  35  address                5555 non-null   object
#  36  availability           5555 non-null   object
#  37  review_scores          5555 non-null   object
#  38  reviews                5555 non-null   object
#  39  weekly_price           714 non-null    object
#  40  monthly_price          656 non-null    object
#  41  reviews_per_month      94 non-null     float64
# dtypes: datetime64[ns](4), float64(3), int64(2), object(33)
# memory usage: 1.8+ MB

# %%
df.isnull().sum()
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1388
# last_review              1388
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         2084
# cleaning_fee             1531
# extra_people                0
# guests_included             0
# images                      0
# host                        0
# address                     0
# availability                0
# review_scores               0
# reviews                     0
# weekly_price             4841
# monthly_price            4899
# reviews_per_month        5461
# dtype: int64

# %%
#Drop columns On the basis of:-
#1. least importance
#2. unique features
#3. null values

# %%
data = df.drop(['_id','listing_url','summary','name','space','description','neighborhood_overview','notes','transit','access','interaction','house_rules','amenities', 'images', 'host', 'address', 'availability', 'review_scores', 'reviews','reviews_per_month','monthly_price','weekly_price','first_review','last_review','cleaning_fee','security_deposit'], axis = 'columns')

# %%
data.head(10)
# Out:
#   property_type        room_type  bed_type minimum_nights maximum_nights  \
# 0     Apartment  Entire home/apt  Real Bed              3             75
# 1     Apartment  Entire home/apt  Real Bed              2           1125
# 2         House  Entire home/apt  Real Bed              2             30
# 3     Apartment     Private room  Real Bed              1           1125
# 4   Condominium  Entire home/apt  Real Bed              3            365
# 5     Apartment     Private room  Real Bed             12            360
# 6     Apartment  Entire home/apt  Real Bed              4             20
# 7     Apartment  Entire home/apt  Real Bed              1           1125
# 8     Apartment  Entire home/apt  Real Bed              1           1125
# 9     Apartment  Entire home/apt  Real Bed              1           1125
#
#            cancellation_policy        last_scraped calendar_last_scraped  \
# 0  strict_14_with_grace_period 2019-02-11 05:00:00   2019-02-11 05:00:00
# 1                     flexible 2019-02-11 05:00:00   2019-02-11 05:00:00
# 2                     moderate 2019-02-16 05:00:00   2019-02-16 05:00:00
# 3  strict_14_with_grace_period 2019-03-11 04:00:00   2019-03-11 04:00:00
# 4  strict_14_with_grace_period 2019-03-06 05:00:00   2019-03-06 05:00:00
# 5  strict_14_with_grace_period 2019-03-07 05:00:00   2019-03-07 05:00:00
# 6                     flexible 2019-03-11 04:00:00   2019-03-11 04:00:00
# 7                     flexible 2019-03-11 04:00:00   2019-03-11 04:00:00
# 8                     flexible 2019-02-11 05:00:00   2019-02-11 05:00:00
# 9                     flexible 2019-02-11 05:00:00   2019-02-11 05:00:00
#
#    accommodates  bedrooms  beds  number_of_reviews bathrooms   price  \
# 0             4       1.0   3.0                 70       2.0  119.00
# 1             4       1.0   2.0                  0       1.0  317.00
# 2             8       3.0   5.0                 51       1.0   80.00
# 3             2       1.0   1.0                  0       1.0  361.00
# 4             2       1.0   1.0                 96       1.0  115.00
# 5             2       1.0   1.0                 70       1.0  135.00
# 6             3       1.0   2.0                  3       1.0  699.00
# 7             6       3.0   3.0                  0       1.0  140.00
# 8             5       3.0   3.0                  0       1.5  933.00
# 9             2       2.0   2.0                  0       1.0  380.00
#
#   extra_people guests_included
# 0        40.00               3
# 1         0.00               1
# 2        15.00               6
# 3       130.00               2
# 4         0.00               1
# 5         0.00               1
# 6         0.00               1
# 7         0.00               1
# 8         0.00               1
# 9         0.00               1

# %%
data.isnull().sum()
# Out:
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# last_scraped              0
# calendar_last_scraped     0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# extra_people              0
# guests_included           0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# property_type            0
# room_type                0
# bed_type                 0
# minimum_nights           0
# maximum_nights           0
# cancellation_policy      0
# last_scraped             0
# calendar_last_scraped    0
# accommodates             0
# bedrooms                 0
# beds                     0
# number_of_reviews        0
# bathrooms                0
# price                    0
# extra_people             0
# guests_included          0
# dtype: int64

# %%
data.shape
# Out:
# (5532, 16)

# %%
data.to_csv('Airbnb.csv', index = True)
